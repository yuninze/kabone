# %% [markdown]
# #### Categorial sorting
# * trainingSemester, trainingCompany

# %%
import numpy as np
import pandas as pd

# %%
data_=pd.read_csv("c:/code/data.csv")
data_.info()
data_[data_.trainingSemester=="3-2"].head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1298 entries, 0 to 1297
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   trainingSemester           1298 non-null   object
#  1   trainingClass              1298 non-null   object
#  2   idx                        1298 non-null   int64
#  3   trainingSerie              1298 non-null   object
#  4   trainingCompany            1298 non-null   object
#  5   trainingPeriod             1298 non-null   object
#  6   name                       1298 non-null   object
#  7   klass                      1152 non-null   object
#  8   trainingTeacher            1298 non-null   object
#  9   trainingUnit               1167 non-null   object
#  10  address                    1298 non-null   object
#  11  registerProblem            1298 non-null   bool
#  12  contact                    854 non-null    object
# ...

# %%
data=data_.sort_values(
    ["trainingSemester","trainingCompany","trainingUnit"]
).assign(
    trainingLeader=np.nan,
    trainingLeaderPosition=np.nan,
    trainingLeaderDegree=np.nan,
    trainingLeaderRn=np.nan,
    trainingLeaderExperience=np.nan)
data[data.columns[-5:]]
# Out:
#       trainingLeader  trainingLeaderPosition  trainingLeaderDegree  \
# 38               NaN                     NaN                   NaN
# 94               NaN                     NaN                   NaN
# 112              NaN                     NaN                   NaN
# 143              NaN                     NaN                   NaN
# 95               NaN                     NaN                   NaN
# ...              ...                     ...                   ...
# 1277             NaN                     NaN                   NaN
# 1274             NaN                     NaN                   NaN
# 1275             NaN                     NaN                   NaN
# 1268             NaN                     NaN                   NaN
# 1271             NaN                     NaN                   NaN
#
#       trainingLeaderRn  trainingLeaderExperience
# 38                 NaN                       NaN
# 94                 NaN                       NaN
# ...

# %% [markdown]
# * Input values one-by-one as raw data in different spreadsheets or papers (unforgiving)

# %%
data=pd.read_clipboard()

# %%
data=data[data.trainingSemester=="4-1"]

# %%
data=data.set_index(["trainingCompany","trainingUnit"])

# %%
y=pd.read_clipboard().set_index(["trainingCompany","trainingUnit"])

# %%
data.update(y,overwrite=True)

# %%
data.reset_index().loc[:,["trainingSemester","trainingClass","idx","trainingSerie","trainingCompany","trainingPeriod","name","klass","trainingTeacher","trainingUnit","address","registerProblem","contact","isFulltimeTrainingTeacher","trainingGroup","trainingClassYear","trainingClassCredit","trainingClassCreditMoney","trainingLeader","trainingLeaderDepartment","trainingLeaderPosition","trainingLeaderDegree","trainingLeaderRn","trainingLeaderExperience"]].to_clipboard(index=0)
